# %%
## Run selenium and chrome driver to scrape data from cloudbytes.dev
import time
import os.path
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.wait import WebDriverWait
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Web scraper part 1

# %%
## Setup chrome options
chrome_options = Options()
chrome_options.headless = True # Ensure GUI is off
chrome_options.add_argument("--window-size=1920,1200")

# Set path to chromedriver as per your configuration
homedir = os.path.expanduser("~")
webdriver_service = Service(f"{homedir}/ao3lockwood-co/chromedriver")

# Choose Chrome Browser
browser = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Get page
pagenum=1
link="https://archiveofourown.org/tags/Lockwood%20*a*%20Co*d*%20-%20Jonathan%20Stroud/works?page="+str(pagenum)
browser.get(link)
maxpagenum=int(browser.find_element(By.XPATH,'//ol[1]/li[13]').text.strip())

def get_title(browser):
    """
    Extracts information for each work on a given page and returns a Pandas DataFrame.
    """
    # Find all the fanfic works on the page
    works = browser.find_elements(By.XPATH, '//ol[2]/li')
    
    # Iterate through each work and extract author and datetime
    data=[]
    for work in works:
        WebDriverWait(browser, 10)
        h4 = work.find_element(By.TAG_NAME,'h4')
        a = h4.find_elements(By.TAG_NAME, 'a')
        title = a[0].text.strip()
        try:
            author = a[1].text.strip()
        except:
            author = "Anonymous"
        links = a[0].get_attribute("href")
        datetime = work.find_element(By.CLASS_NAME, 'datetime').text.strip()
        chapters = work.find_elements(By.CLASS_NAME,'chapters')[1].text.strip()
        row = {'link':links, 
               'title':title,
               'author':author, 
               'updatedate':datetime,
               'chapters':chapters
               }
        #print(row)
        data.append(row)
    return pd.DataFrame(data)

# Create an empty DataFrame to hold the data
data_list = get_title(browser)
print('page 1 has been processed')
# Iterate through each page and append the data to the DataFrame
for p in range(2,maxpagenum+1):
    pagenum=p
    time.sleep(10)
    print(f'procesing page {pagenum}/{maxpagenum}')
    link="https://archiveofourown.org/tags/Lockwood%20*a*%20Co*d*%20-%20Jonathan%20Stroud/works?page="+str(pagenum)
    browser.get(link)
    data_list=data_list.append(get_title(browser), ignore_index=True)
    print(len(data_list))

#Wait for 10 seconds
time.sleep(10)
browser.quit()
# Out:
# page 1 has been processed
# procesing page 2/66
# 40
# procesing page 3/66
# 60
# procesing page 4/66
# 80
# procesing page 5/66
# 100
# procesing page 6/66
# 120
# procesing page 7/66
# 140
# procesing page 8/66
# 160
# procesing page 9/66
# 180
# procesing page 10/66
# 200
# procesing page 11/66
# 220
# procesing page 12/66
# 240
# procesing page 13/66
# 260
# procesing page 14/66
# 280
# procesing page 15/66
# 300
# procesing page 16/66
# 320
# procesing page 17/66
# 340
# procesing page 18/66
# 360
# procesing page 19/66
# 380
# procesing page 20/66
# 400
# procesing page 21/66
# 420
# procesing page 22/66
# 440
# procesing page 23/66
# 460
# procesing page 24/66
# 480
# procesing page 25/66
# 500
# procesing page 26/66
# 520
# procesing page 27/66
# 540
# procesing page 28/66
# 560
# procesing page 29/66
# 580
# procesing page 30/66
# 600
# procesing page 31/66
# 620
# procesing page 32/66
# 640
# procesing page 33/66
# 660
# procesing page 34/66
# 680
# procesing page 35/66
# 700
# procesing page 36/66
# 720
# procesing page 37/66
# 740
# procesing page 38/66
# 760
# procesing page 39/66
# 780
# procesing page 40/66
# 800
# procesing page 41/66
# 820
# procesing page 42/66
# 840
# procesing page 43/66
# 860
# procesing page 44/66
# 880
# procesing page 45/66
# 900
# procesing page 46/66
# 920
# procesing page 47/66
# 940
# procesing page 48/66
# 960
# procesing page 49/66
# 980
# procesing page 50/66
# 1000
# procesing page 51/66
# 1020
# procesing page 52/66
# 1040
# procesing page 53/66
# 1060
# procesing page 54/66
# 1080
# procesing page 55/66
# 1100
# procesing page 56/66
# 1120
# procesing page 57/66
# 1140
# procesing page 58/66
# 1160
# procesing page 59/66
# 1180
# procesing page 60/66
# 1200
# procesing page 61/66
# 1220
# procesing page 62/66
# 1240
# procesing page 63/66
# 1260
# procesing page 64/66
# 1280
# procesing page 65/66
# 1300
# procesing page 66/66
# 1318

# %%
# Split the chapter column into chapter and chapter_max, and create a completion column
data_list[['chapter','chapter_max']] = data_list.chapters.str.split("/", expand=True)
data_list['completion'] = data_list.apply(lambda row: 'completed' if row['chapter']==row['chapter_max'] else 'incomplete', axis=1)

data_list1=data_list.replace('', np.nan)
data_list1=data_list1[data_list1.isna().any(axis=1)]
def get_missing1(df):
    data=[]
    counter=0
    for x in df['link']:
        newlink=x+'?view_adult=true'
        counter+=1
        print(f"getting missing data {counter}/{len(df['link'])}")
        source = requests.get(newlink, headers={
                          'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64)'}).text
        soup = BeautifulSoup(source,'html.parser')
        title=soup.find('h2', attrs={'class':'title heading'}).get_text().replace('\n','').strip()
        try:
            author=soup.find('a', attrs={'rel':'author'}).get_text()
        except:
            author="Anonymous"
        datetime=soup.find('dd', attrs={'class':'published'}).get_text()
        chapters=soup.find('dd', attrs={'class':'chapters'}).get_text()
        row = {'link':x, 
               'title':title,
               'author':author, 
               'updatedate':datetime,
               'chapters':chapters
               }
        #print(row)
        data.append(row)
        time.sleep(10)
    return pd.DataFrame(data)
if len(data_list1)==0:
    part1=data_list
else:
    data_list2 = data_list[~data_list['link'].isin(data_list1['link'])]
    data_list3=get_missing1(data_list1)
    # Split the chapter column into chapter and chapter_max, and create a completion column
    data_list3[['chapter','chapter_max']] = data_list3.chapters.str.split("/", expand=True)
    data_list3['completion'] = data_list3.apply(lambda row: 'completed' if row['chapter']==row['chapter_max'] else 'incomplete', axis=1)
    part1=data_list2.append(data_list3)
#data_listfinal.to_csv('lockwood_part1.csv', index=False)
print(part1[part1.isna().any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [link, title, author, updatedate, chapters, chapter, chapter_max, completion]
# Index: []

# %% [markdown]
# # Web scraper part 2

# %%
## Setup chrome options
chrome_options = Options()
chrome_options.headless = True # Ensure GUI is off
chrome_options.add_argument("--window-size=1920,1200")

# Set path to chromedriver as per your configuration
homedir = os.path.expanduser("~")
webdriver_service = Service(f"{homedir}/ao3lockwood-co/chromedriver")

# Choose Chrome Browser
browser = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Get page
pagenum=1
link="https://archiveofourown.org/tags/Lockwood%20*a*%20Co*d*%20-%20Jonathan%20Stroud/works?page="+str(pagenum)
browser.get(link)

# Get the total number of pages to scrape
maxpagenum=int(browser.find_element(By.XPATH,'//ol[1]/li[13]').text.strip())

def get_user(browser):
    """
    Extracts data from each work listed on a page.
    :param browser: Chrome Webdriver object
    :return: Pandas DataFrame
    """
    # Find all the fanfic works on the page
    works = browser.find_elements(By.XPATH, '//ol[2]/li')
    # Iterate through each work and extract author and datetime
    data=[]
    for work in works:
        WebDriverWait(browser, 10)
        h4 = work.find_element(By.TAG_NAME,'h4')
        a = h4.find_elements(By.TAG_NAME, 'a')
        links = a[0].get_attribute("href")
        language = work.find_elements(By.CLASS_NAME,'language')[1].text.strip()
        words = work.find_elements(By.CLASS_NAME,'words')[1].text.strip()
        try:
            kudos = work.find_elements(By.CLASS_NAME,'kudos')[1].text.strip()
        except:
            kudos = 0
        try:
            hits = work.find_elements(By.CLASS_NAME,'hits')[1].text.strip()
        except:
            hits = 0
        try:
            comments = work.find_elements(By.CLASS_NAME,'comments')[1].text.strip()
        except:
            comments = 0
        try:
            bookmarks = work.find_elements(By.CLASS_NAME,'bookmarks')[1].text.strip()
        except:
            bookmarks = 0
        row = {'link':links, 
               'language':language,
               'words':words,
               'kudos':kudos, 
               'comments':comments,
               'bookmarks':bookmarks,
               'hits':hits
               }
        data.append(row)
        
    return pd.DataFrame(data)

# Get data from the first page
data_list=get_user(browser)
print('page 1 processed')

# Iterate through remaining pages
for p in range(2,maxpagenum+1):
    pagenum=p
    time.sleep(10)
    print(f'procesing page {pagenum}/{maxpagenum}')
    link="https://archiveofourown.org/tags/Lockwood%20*a*%20Co*d*%20-%20Jonathan%20Stroud/works?page="+str(pagenum)
    browser.get(link)
    data_list=data_list.append(get_user(browser), ignore_index=True)
    print(len(data_list))

# Wait for 10 seconds
time.sleep(10)
browser.quit()
# Out:
# page 1 processed
# procesing page 2/66
# 40
# procesing page 3/66
# 60
# procesing page 4/66
# 80
# procesing page 5/66
# 100
# procesing page 6/66
# 120
# procesing page 7/66
# 140
# procesing page 8/66
# 160
# procesing page 9/66
# 180
# procesing page 10/66
# 200
# procesing page 11/66
# 220
# procesing page 12/66
# 240
# procesing page 13/66
# 260
# procesing page 14/66
# 280
# procesing page 15/66
# 300
# procesing page 16/66
# 320
# procesing page 17/66
# 340
# procesing page 18/66
# 360
# procesing page 19/66
# 380
# procesing page 20/66
# 400
# procesing page 21/66
# 420
# procesing page 22/66
# 440
# procesing page 23/66
# 460
# procesing page 24/66
# 480
# procesing page 25/66
# 500
# procesing page 26/66
# 520
# procesing page 27/66
# 540
# procesing page 28/66
# 560
# procesing page 29/66
# 580
# procesing page 30/66
# 600
# procesing page 31/66
# 620
# procesing page 32/66
# 640
# procesing page 33/66
# 660
# procesing page 34/66
# 680
# procesing page 35/66
# 700
# procesing page 36/66
# 720
# procesing page 37/66
# 740
# procesing page 38/66
# 760
# procesing page 39/66
# 780
# procesing page 40/66
# 800
# procesing page 41/66
# 820
# procesing page 42/66
# 840
# procesing page 43/66
# 860
# procesing page 44/66
# 880
# procesing page 45/66
# 900
# procesing page 46/66
# 920
# procesing page 47/66
# 940
# procesing page 48/66
# 960
# procesing page 49/66
# 980
# procesing page 50/66
# 1000
# procesing page 51/66
# 1020
# procesing page 52/66
# 1040
# procesing page 53/66
# 1060
# procesing page 54/66
# 1080
# procesing page 55/66
# 1100
# procesing page 56/66
# 1120
# procesing page 57/66
# 1140
# procesing page 58/66
# 1160
# procesing page 59/66
# 1180
# procesing page 60/66
# 1200
# procesing page 61/66
# 1220
# procesing page 62/66
# 1240
# procesing page 63/66
# 1260
# procesing page 64/66
# 1280
# procesing page 65/66
# 1300
# procesing page 66/66
# 1318

# %%
# Remove empty cells and create a new DataFrame with missing data
data_list1=data_list.replace('', np.nan)
data_list1=data_list1[data_list1.isna().any(axis=1)]
data_list2 = data_list[~data_list['link'].isin(data_list1['link'])]

def get_missing2(df):
    """
    Extracts data for works that had missing cells in the original DataFrame.
    :param df: Pandas DataFrame
    :return: Pandas DataFrame
    """
    data=[]
    counter=0
    for x in df['link']:
        newlink=x+'?view_adult=true'
        counter+=1
        print(f"getting missing data {counter}/{len(df['link'])}")
        source = requests.get(newlink, headers={
                          'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64)'}).text
        soup = BeautifulSoup(source,'html.parser')
        language=soup.find('dd', attrs={'class':'language'}).get_text().replace('\n','').strip()
        words=soup.find('dd', attrs={'class':'words'}).get_text()
        try:
            kudos=soup.find('dd', attrs={'class':'kudos'}).get_text()
        except:
            kudos=0
        try:
            comments=soup.find('dd', attrs={'class':'comments'}).get_text()
        except:
            comments=0
        try:
            bookmarks=soup.find('dd', attrs={'class':'bookmarks'}).get_text()
        except:
            bookmarks=0
        try:
            hits=soup.find('dd', attrs={'class':'hits'}).get_text()
        except:
            hits=0
        row = {'link':x, 
               'language':language,
               'words':words,
               'kudos':kudos, 
               'comments':comments,
               'bookmarks':bookmarks,
               'hits':hits
               }
        #print(row)
        data.append(row)
        time.sleep(10)
    return pd.DataFrame(data)
if len(data_list1)==0:
    part2 = data_list
else:
    data_list3=get_missing2(data_list1)
    part2=data_list2.append(data_list3)
print(part2[part2.isna().any(axis=1)])
# Out:
# getting missing data 1/249
# getting missing data 2/249
# getting missing data 3/249
# getting missing data 4/249
# getting missing data 5/249
# getting missing data 6/249
# getting missing data 7/249
# getting missing data 8/249
# getting missing data 9/249
# getting missing data 10/249
# getting missing data 11/249
# getting missing data 12/249
# getting missing data 13/249
# getting missing data 14/249
# getting missing data 15/249
# getting missing data 16/249
# getting missing data 17/249
# getting missing data 18/249
# getting missing data 19/249
# getting missing data 20/249
# getting missing data 21/249
# getting missing data 22/249
# getting missing data 23/249
# getting missing data 24/249
# getting missing data 25/249
# getting missing data 26/249
# getting missing data 27/249
# getting missing data 28/249
# getting missing data 29/249
# getting missing data 30/249
# getting missing data 31/249
# getting missing data 32/249
# getting missing data 33/249
# getting missing data 34/249
# getting missing data 35/249
# getting missing data 36/249
# getting missing data 37/249
# getting missing data 38/249
# getting missing data 39/249
# getting missing data 40/249
# getting missing data 41/249
# getting missing data 42/249
# getting missing data 43/249
# getting missing data 44/249
# getting missing data 45/249
# getting missing data 46/249
# getting missing data 47/249
# getting missing data 48/249
# getting missing data 49/249
# getting missing data 50/249
# getting missing data 51/249
# getting missing data 52/249
# getting missing data 53/249
# getting missing data 54/249
# getting missing data 55/249
# getting missing data 56/249
# getting missing data 57/249
# getting missing data 58/249
# getting missing data 59/249
# getting missing data 60/249
# getting missing data 61/249
# getting missing data 62/249
# getting missing data 63/249
# getting missing data 64/249
# getting missing data 65/249
# getting missing data 66/249
# getting missing data 67/249
# getting missing data 68/249
# getting missing data 69/249
# getting missing data 70/249
# getting missing data 71/249
# getting missing data 72/249
# getting missing data 73/249
# getting missing data 74/249
# getting missing data 75/249
# getting missing data 76/249
# getting missing data 77/249
# getting missing data 78/249
# getting missing data 79/249
# getting missing data 80/249
# getting missing data 81/249
# getting missing data 82/249
# getting missing data 83/249
# getting missing data 84/249
# getting missing data 85/249
# getting missing data 86/249
# getting missing data 87/249
# getting missing data 88/249
# getting missing data 89/249
# getting missing data 90/249
# getting missing data 91/249
# getting missing data 92/249
# getting missing data 93/249
# getting missing data 94/249
# getting missing data 95/249
# getting missing data 96/249
# getting missing data 97/249
# getting missing data 98/249
# getting missing data 99/249
# getting missing data 100/249
# getting missing data 101/249
# getting missing data 102/249
# getting missing data 103/249
# getting missing data 104/249
# getting missing data 105/249
# getting missing data 106/249
# getting missing data 107/249
# getting missing data 108/249
# getting missing data 109/249
# getting missing data 110/249
# getting missing data 111/249
# getting missing data 112/249
# getting missing data 113/249
# getting missing data 114/249
# getting missing data 115/249
# getting missing data 116/249
# getting missing data 117/249
# getting missing data 118/249
# getting missing data 119/249
# getting missing data 120/249
# getting missing data 121/249
# getting missing data 122/249
# getting missing data 123/249
# getting missing data 124/249
# getting missing data 125/249
# getting missing data 126/249
# getting missing data 127/249
# getting missing data 128/249
# getting missing data 129/249
# getting missing data 130/249
# getting missing data 131/249
# getting missing data 132/249
# getting missing data 133/249
# getting missing data 134/249
# getting missing data 135/249
# getting missing data 136/249
# getting missing data 137/249
# getting missing data 138/249
# getting missing data 139/249
# getting missing data 140/249
# getting missing data 141/249
# getting missing data 142/249
# getting missing data 143/249
# getting missing data 144/249
# getting missing data 145/249
# getting missing data 146/249
# getting missing data 147/249
# getting missing data 148/249
# getting missing data 149/249
# getting missing data 150/249
# getting missing data 151/249
# getting missing data 152/249
# getting missing data 153/249
# getting missing data 154/249
# getting missing data 155/249
# getting missing data 156/249
# getting missing data 157/249
# getting missing data 158/249
# getting missing data 159/249
# getting missing data 160/249
# getting missing data 161/249
# getting missing data 162/249
# getting missing data 163/249
# getting missing data 164/249
# getting missing data 165/249
# getting missing data 166/249
# getting missing data 167/249
# getting missing data 168/249
# getting missing data 169/249
# getting missing data 170/249
# getting missing data 171/249
# getting missing data 172/249
# getting missing data 173/249
# getting missing data 174/249
# getting missing data 175/249
# getting missing data 176/249
# getting missing data 177/249
# getting missing data 178/249
# getting missing data 179/249
# getting missing data 180/249
# getting missing data 181/249
# getting missing data 182/249
# getting missing data 183/249
# getting missing data 184/249
# getting missing data 185/249
# getting missing data 186/249
# getting missing data 187/249
# getting missing data 188/249
# getting missing data 189/249
# getting missing data 190/249
# getting missing data 191/249
# getting missing data 192/249
# getting missing data 193/249
# getting missing data 194/249
# getting missing data 195/249
# getting missing data 196/249
# getting missing data 197/249
# getting missing data 198/249
# getting missing data 199/249
# getting missing data 200/249
# getting missing data 201/249
# getting missing data 202/249
# getting missing data 203/249
# getting missing data 204/249
# getting missing data 205/249
# getting missing data 206/249
# getting missing data 207/249
# getting missing data 208/249
# getting missing data 209/249
# getting missing data 210/249
# getting missing data 211/249
# getting missing data 212/249
# getting missing data 213/249
# getting missing data 214/249
# getting missing data 215/249
# getting missing data 216/249
# getting missing data 217/249
# getting missing data 218/249
# getting missing data 219/249
# getting missing data 220/249
# getting missing data 221/249
# getting missing data 222/249
# getting missing data 223/249
# getting missing data 224/249
# getting missing data 225/249
# getting missing data 226/249
# getting missing data 227/249
# getting missing data 228/249
# getting missing data 229/249
# getting missing data 230/249
# getting missing data 231/249
# getting missing data 232/249
# getting missing data 233/249
# getting missing data 234/249
# getting missing data 235/249
# getting missing data 236/249
# getting missing data 237/249
# getting missing data 238/249
# getting missing data 239/249
# getting missing data 240/249
# getting missing data 241/249
# getting missing data 242/249
# getting missing data 243/249
# getting missing data 244/249
# getting missing data 245/249
# getting missing data 246/249
# getting missing data 247/249
# getting missing data 248/249
# getting missing data 249/249
# Empty DataFrame
# Columns: [link, language, words, kudos, comments, bookmarks, hits]
# Index: []

# %% [markdown]
# # Web scraper part 3

# %%
## Setup chrome options
chrome_options = Options()
chrome_options.headless = True # Ensure GUI is off
chrome_options.add_argument("--window-size=1920,1200")

# Set path to chromedriver as per your configuration
homedir = os.path.expanduser("~")
webdriver_service = Service(f"{homedir}/ao3lockwood-co/chromedriver")

# Choose Chrome Browser
browser = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Get page
pagenum=1
link="https://archiveofourown.org/tags/Lockwood%20*a*%20Co*d*%20-%20Jonathan%20Stroud/works?page="+str(pagenum)
browser.get(link)

# Get the total number of pages to scrape
maxpagenum=int(browser.find_element(By.XPATH,'//ol[1]/li[13]').text.strip())

def get_text(browser):
    """
    Extracts data from each work listed on a page.
    :param browser: Chrome Webdriver object
    :return: Pandas DataFrame
    """
    # Find all the fanfic works on the page
    works = browser.find_elements(By.XPATH, '//ol[2]/li')
    # Iterate through each work and extract author and datetime
    data=[]
    for work in works:
        WebDriverWait(browser, 10)
        h4 = work.find_element(By.TAG_NAME,'h4')
        a = h4.find_elements(By.TAG_NAME, 'a')
        links = a[0].get_attribute("href")
        warning=work.find_element(By.TAG_NAME,'strong').text.strip()
        try:
            mainrelationship = work.find_element(By.CLASS_NAME,'relationships').text.strip()
            relationship_list = []
            relationship = work.find_elements(By.CLASS_NAME,'relationships')
            for r in relationship:
                relationship_list.append(r.text.strip())
        except:
            mainrelationship = np.nan
            relationship_list = np.nan
        character_list = []
        characters = work.find_elements(By.CLASS_NAME, 'characters')
        for char in characters:
            character_list.append(char.text.strip())
        try:
            tags_list = []
            tags = work.find_elements(By.CLASS_NAME,'freeforms')
            for tag in tags:
                tags_list.append(tag.text.strip())
        except:
            tags_list=np.nan
        summary = work.find_element(By.TAG_NAME, 'blockquote').text.replace('\n',' ').strip()
        row = {'link':links, 
               'warning':warning,
               'mainship':mainrelationship,
               'relationship':relationship_list,
               'characters':character_list, 
               'tags':tags_list,
               'summary':summary
               }
        data.append(row)
    return pd.DataFrame(data)

# Get data from the first page
data_list=get_text(browser)
print('page 1 processed')
# Iterate through remaining pages
for p in range(2,maxpagenum+1):
    pagenum=p
    time.sleep(10)
    print(f'procesing page {pagenum}/{maxpagenum}')
    link="https://archiveofourown.org/tags/Lockwood%20*a*%20Co*d*%20-%20Jonathan%20Stroud/works?page="+str(pagenum)
    browser.get(link)
    data_list=data_list.append(get_text(browser), ignore_index=True)
    print(len(data_list))

#Wait for 10 seconds
time.sleep(10)
browser.quit()
# Out:
# page 1 processed
# procesing page 2/66
# 40
# procesing page 3/66
# 60
# procesing page 4/66
# 80
# procesing page 5/66
# 100
# procesing page 6/66
# 120
# procesing page 7/66
# 140
# procesing page 8/66
# 160
# procesing page 9/66
# 180
# procesing page 10/66
# 200
# procesing page 11/66
# 220
# procesing page 12/66
# 240
# procesing page 13/66
# 260
# procesing page 14/66
# 280
# procesing page 15/66
# 300
# procesing page 16/66
# 320
# procesing page 17/66
# 340
# procesing page 18/66
# 360
# procesing page 19/66
# 380
# procesing page 20/66
# 400
# procesing page 21/66
# 420
# procesing page 22/66
# 440
# procesing page 23/66
# 460
# procesing page 24/66
# 480
# procesing page 25/66
# 500
# procesing page 26/66
# 520
# procesing page 27/66
# 540
# procesing page 28/66
# 560
# procesing page 29/66
# 580
# procesing page 30/66
# 600
# procesing page 31/66
# 620
# procesing page 32/66
# 640
# procesing page 33/66
# 660
# procesing page 34/66
# 680
# procesing page 35/66
# 700
# procesing page 36/66
# 720
# procesing page 37/66
# 740
# procesing page 38/66
# 760
# procesing page 39/66
# 780
# procesing page 40/66
# 800
# procesing page 41/66
# 820
# procesing page 42/66
# 840
# procesing page 43/66
# 860
# procesing page 44/66
# 880
# procesing page 45/66
# 900
# procesing page 46/66
# 920
# procesing page 47/66
# 940
# procesing page 48/66
# 960
# procesing page 49/66
# 980
# procesing page 50/66
# 1000
# procesing page 51/66
# 1020
# procesing page 52/66
# 1040
# procesing page 53/66
# 1060
# procesing page 54/66
# 1080
# procesing page 55/66
# 1100
# procesing page 56/66
# 1120
# procesing page 57/66
# 1140
# procesing page 58/66
# 1160
# procesing page 59/66
# 1180
# procesing page 60/66
# 1200
# procesing page 61/66
# 1220
# procesing page 62/66
# 1240
# procesing page 63/66
# 1260
# procesing page 64/66
# 1280
# procesing page 65/66
# 1300
# procesing page 66/66
# 1320

# %%
data_list1=data_list.replace('', np.nan)
data_list1=data_list1[data_list1.isna().any(axis=1)]

data_list2 = data_list[~data_list['link'].isin(data_list1['link'])]

def get_missing3(df):
    data=[]
    counter=0
    for x in df['link']:
        newlink=x+'?view_adult=true'
        counter+=1
        print(f"getting missing data {counter}/{len(df['link'])}")
        print(newlink)
        source = requests.get(newlink, headers={
                          'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64)'}).text
        soup = BeautifulSoup(source,'html.parser')
        warning=soup.find('dd', attrs={'class':'warning tags'}).get_text().replace('\n','').strip()
        try:
            ships = soup.find('dd', attrs={'class':'relationship tags'})
            ships_list=ships.find_all('a', attrs={'class':'tag'})
            mainrelationship = ships_list[0].get_text().strip()
            relationship_list = []
            for r in ships_list:
                relationship_list.append(r.get_text().strip())
        except:
            mainrelationship='None'
            relationship_list = []
        try:
            char = soup.find('dd', attrs={'class':'character tags'})
            char_list=char.find_all('a', attrs={'class':'tag'})
            character_list = []
            for c in char_list:
                character_list.append(c.get_text().strip())
        except:
            character_list=[]
        try:
            freeform = soup.find('dd', attrs={'class':'freeform tags'})
            freefom_list=freeform.find_all('a', attrs={'class':'tag'})
            tags_list = []
            for t in freefom_list:
                tags_list.append(t.get_text().strip())
        except:
            tags_list = []
        try:
            summary=soup.find('div', attrs={'class':'summary module'}).get_text().replace('\n', ' ').replace('Summary:','').strip()
        except:
            summary=np.nan
        row = {'link':x, 
               'warning':warning,
               'mainship':mainrelationship,
               'relationship':relationship_list,
               'characters':character_list, 
               'tags':tags_list,
               'summary':summary
               }
        #print(row)
        data.append(row)
        time.sleep(10)
    return pd.DataFrame(data)
if len(data_list1)==0:
    part2 = data_list
else:
    data_list3=get_missing3(data_list1)
    part3=data_list2.append(data_list3)
print(part3[part3.isna().any(axis=1)])
# Out:
# getting missing data 1/866
# https://archiveofourown.org/works/46616701?view_adult=true
# getting missing data 2/866
# https://archiveofourown.org/works/46545298?view_adult=true
# getting missing data 3/866
# https://archiveofourown.org/works/46633966?view_adult=true
# getting missing data 4/866
# https://archiveofourown.org/works/46632634?view_adult=true
# getting missing data 5/866
# https://archiveofourown.org/works/46234456?view_adult=true
# getting missing data 6/866
# https://archiveofourown.org/works/46568050?view_adult=true
# getting missing data 7/866
# https://archiveofourown.org/works/46546858?view_adult=true
# getting missing data 8/866
# https://archiveofourown.org/works/46588315?view_adult=true
# getting missing data 9/866
# https://archiveofourown.org/works/46626169?view_adult=true
# getting missing data 10/866
# https://archiveofourown.org/works/45308677?view_adult=true
# getting missing data 11/866
# https://archiveofourown.org/works/46616434?view_adult=true
# getting missing data 12/866
# https://archiveofourown.org/works/46616116?view_adult=true
# getting missing data 13/866
# https://archiveofourown.org/works/46481659?view_adult=true
# getting missing data 14/866
# https://archiveofourown.org/works/45743218?view_adult=true
# getting missing data 15/866
# https://archiveofourown.org/works/46450045?view_adult=true
# getting missing data 16/866
# https://archiveofourown.org/works/46609009?view_adult=true
# getting missing data 17/866
# https://archiveofourown.org/works/46227607?view_adult=true
# getting missing data 18/866
# https://archiveofourown.org/works/46606960?view_adult=true
# getting missing data 19/866
# https://archiveofourown.org/works/44688367?view_adult=true
# getting missing data 20/866
# https://archiveofourown.org/works/46464568?view_adult=true
# getting missing data 21/866
# https://archiveofourown.org/works/46093528?view_adult=true
# getting missing data 22/866
# https://archiveofourown.org/works/46597123?view_adult=true
# getting missing data 23/866
# https://archiveofourown.org/works/46381468?view_adult=true
# getting missing data 24/866
# https://archiveofourown.org/works/45773677?view_adult=true
# getting missing data 25/866
# https://archiveofourown.org/works/46266553?view_adult=true
# getting missing data 26/866
# https://archiveofourown.org/works/46128526?view_adult=true
# getting missing data 27/866
# https://archiveofourown.org/works/46593232?view_adult=true
# getting missing data 28/866
# https://archiveofourown.org/works/46183210?view_adult=true
# getting missing data 29/866
# https://archiveofourown.org/works/46229668?view_adult=true
# getting missing data 30/866
# https://archiveofourown.org/works/46586020?view_adult=true
# getting missing data 31/866
# https://archiveofourown.org/works/46466728?view_adult=true
# getting missing data 32/866
# https://archiveofourown.org/works/46585030?view_adult=true
# getting missing data 33/866
# https://archiveofourown.org/works/46544200?view_adult=true
# getting missing data 34/866
# https://archiveofourown.org/works/46466170?view_adult=true
# getting missing data 35/866
# https://archiveofourown.org/works/45817276?view_adult=true
# getting missing data 36/866
# https://archiveofourown.org/works/46211653?view_adult=true
# getting missing data 37/866
# https://archiveofourown.org/works/46366897?view_adult=true
# getting missing data 38/866
# https://archiveofourown.org/works/46575103?view_adult=true
# getting missing data 39/866
# https://archiveofourown.org/works/46280236?view_adult=true
# getting missing data 40/866
# https://archiveofourown.org/works/45552637?view_adult=true
# getting missing data 41/866
# https://archiveofourown.org/works/46570273?view_adult=true
# getting missing data 42/866
# https://archiveofourown.org/works/46232947?view_adult=true
# getting missing data 43/866
# https://archiveofourown.org/works/46557160?view_adult=true
# getting missing data 44/866
# https://archiveofourown.org/works/44782213?view_adult=true
# getting missing data 45/866
# https://archiveofourown.org/works/46552432?view_adult=true
# getting missing data 46/866
# https://archiveofourown.org/works/46552339?view_adult=true
# getting missing data 47/866
# https://archiveofourown.org/works/46548598?view_adult=true
# getting missing data 48/866
# https://archiveofourown.org/works/46545607?view_adult=true
# getting missing data 49/866
# https://archiveofourown.org/works/46512439?view_adult=true
# getting missing data 50/866
# https://archiveofourown.org/works/46544185?view_adult=true
# getting missing data 51/866
# https://archiveofourown.org/works/46225141?view_adult=true
# getting missing data 52/866
# https://archiveofourown.org/works/46108750?view_adult=true
# getting missing data 53/866
# https://archiveofourown.org/works/46533181?view_adult=true
# getting missing data 54/866
# https://archiveofourown.org/works/46036882?view_adult=true
# getting missing data 55/866
# https://archiveofourown.org/works/45361381?view_adult=true
# getting missing data 56/866
# https://archiveofourown.org/works/46374463?view_adult=true
# getting missing data 57/866
# https://archiveofourown.org/works/46408204?view_adult=true
# getting missing data 58/866
# https://archiveofourown.org/works/46235371?view_adult=true
# getting missing data 59/866
# https://archiveofourown.org/works/46510540?view_adult=true
# getting missing data 60/866
# https://archiveofourown.org/works/46445644?view_adult=true
# getting missing data 61/866
# https://archiveofourown.org/works/46367782?view_adult=true
# getting missing data 62/866
# https://archiveofourown.org/works/46493629?view_adult=true
# getting missing data 63/866
# https://archiveofourown.org/works/46489912?view_adult=true
# getting missing data 64/866
# https://archiveofourown.org/works/46490665?view_adult=true
# getting missing data 65/866
# https://archiveofourown.org/works/46315132?view_adult=true
# getting missing data 66/866
# https://archiveofourown.org/works/46085413?view_adult=true
# getting missing data 67/866
# https://archiveofourown.org/works/46474255?view_adult=true
# getting missing data 68/866
# https://archiveofourown.org/works/46473562?view_adult=true
# getting missing data 69/866
# https://archiveofourown.org/works/46295881?view_adult=true
# getting missing data 70/866
# https://archiveofourown.org/works/42140697?view_adult=true
# getting missing data 71/866
# https://archiveofourown.org/works/46461532?view_adult=true
# getting missing data 72/866
# https://archiveofourown.org/works/46458169?view_adult=true
# getting missing data 73/866
# https://archiveofourown.org/works/46454686?view_adult=true
# getting missing data 74/866
# https://archiveofourown.org/works/46452142?view_adult=true
# getting missing data 75/866
# https://archiveofourown.org/works/46451566?view_adult=true
# getting missing data 76/866
# https://archiveofourown.org/works/45625834?view_adult=true
# getting missing data 77/866
# https://archiveofourown.org/works/46447390?view_adult=true
# getting missing data 78/866
# https://archiveofourown.org/works/46446364?view_adult=true
# getting missing data 79/866
# https://archiveofourown.org/works/46266304?view_adult=true
# getting missing data 80/866
# https://archiveofourown.org/works/46431190?view_adult=true
# getting missing data 81/866
# https://archiveofourown.org/works/46433071?view_adult=true
# getting missing data 82/866
# https://archiveofourown.org/works/46432357?view_adult=true
# getting missing data 83/866
# https://archiveofourown.org/works/46431946?view_adult=true
# getting missing data 84/866
# https://archiveofourown.org/works/46431418?view_adult=true
# getting missing data 85/866
# https://archiveofourown.org/works/45992374?view_adult=true
# getting missing data 86/866
# https://archiveofourown.org/works/46415074?view_adult=true
# getting missing data 87/866
# https://archiveofourown.org/works/45139474?view_adult=true
# getting missing data 88/866
# https://archiveofourown.org/works/46410094?view_adult=true
# getting missing data 89/866
# https://archiveofourown.org/works/45883108?view_adult=true
# getting missing data 90/866
# https://archiveofourown.org/works/45289729?view_adult=true
# getting missing data 91/866
# https://archiveofourown.org/works/46403539?view_adult=true
# getting missing data 92/866
# https://archiveofourown.org/works/46403062?view_adult=true
# getting missing data 93/866
# https://archiveofourown.org/works/46400428?view_adult=true
# getting missing data 94/866
# https://archiveofourown.org/works/46401100?view_adult=true
# getting missing data 95/866
# https://archiveofourown.org/works/42711834?view_adult=true
# getting missing data 96/866
# https://archiveofourown.org/works/46395415?view_adult=true
# getting missing data 97/866
# https://archiveofourown.org/works/46388950?view_adult=true
# getting missing data 98/866
# https://archiveofourown.org/works/46360597?view_adult=true
# getting missing data 99/866
# https://archiveofourown.org/works/45416176?view_adult=true
# getting missing data 100/866
# https://archiveofourown.org/works/46369297?view_adult=true
# getting missing data 101/866
# https://archiveofourown.org/works/46201771?view_adult=true
# getting missing data 102/866
# https://archiveofourown.org/works/45638332?view_adult=true
# getting missing data 103/866
# https://archiveofourown.org/works/46360966?view_adult=true
# getting missing data 104/866
# https://archiveofourown.org/works/46358539?view_adult=true
# getting missing data 105/866
# https://archiveofourown.org/works/46358098?view_adult=true
# getting missing data 106/866
# https://archiveofourown.org/works/46358089?view_adult=true
# getting missing data 107/866
# https://archiveofourown.org/works/45064558?view_adult=true
# getting missing data 108/866
# https://archiveofourown.org/works/46353790?view_adult=true
# getting missing data 109/866
# https://archiveofourown.org/works/46351537?view_adult=true
# getting missing data 110/866
# https://archiveofourown.org/works/46282243?view_adult=true
# getting missing data 111/866
# https://archiveofourown.org/works/45307531?view_adult=true
# getting missing data 112/866
# https://archiveofourown.org/works/46346389?view_adult=true
# getting missing data 113/866
# https://archiveofourown.org/works/46345342?view_adult=true
# getting missing data 114/866
# https://archiveofourown.org/works/46329682?view_adult=true
# getting missing data 115/866
# https://archiveofourown.org/works/46326508?view_adult=true
# getting missing data 116/866
# https://archiveofourown.org/works/46325347?view_adult=true
# getting missing data 117/866
# https://archiveofourown.org/works/46325395?view_adult=true
# getting missing data 118/866
# https://archiveofourown.org/works/46324702?view_adult=true
# getting missing data 119/866
# https://archiveofourown.org/works/45505162?view_adult=true
# getting missing data 120/866
# https://archiveofourown.org/works/45928231?view_adult=true
# getting missing data 121/866
# https://archiveofourown.org/works/45965344?view_adult=true
# getting missing data 122/866
# https://archiveofourown.org/works/45474004?view_adult=true
# getting missing data 123/866
# https://archiveofourown.org/works/46320637?view_adult=true
# getting missing data 124/866
# https://archiveofourown.org/works/46318897?view_adult=true
# getting missing data 125/866
# https://archiveofourown.org/works/46317319?view_adult=true
# getting missing data 126/866
# https://archiveofourown.org/works/46288870?view_adult=true
# getting missing data 127/866
# https://archiveofourown.org/works/46257373?view_adult=true
# getting missing data 128/866
# https://archiveofourown.org/works/46066087?view_adult=true
# getting missing data 129/866
# https://archiveofourown.org/works/46295896?view_adult=true
# getting missing data 130/866
# https://archiveofourown.org/works/46286233?view_adult=true
# getting missing data 131/866
# https://archiveofourown.org/works/46286143?view_adult=true
# getting missing data 132/866
# https://archiveofourown.org/works/46281751?view_adult=true
# getting missing data 133/866
# https://archiveofourown.org/works/46275070?view_adult=true
# getting missing data 134/866
# https://archiveofourown.org/works/46269961?view_adult=true
# getting missing data 135/866
# https://archiveofourown.org/works/46271611?view_adult=true
# getting missing data 136/866
# https://archiveofourown.org/works/46056190?view_adult=true
# getting missing data 137/866
# https://archiveofourown.org/works/46266283?view_adult=true
# getting missing data 138/866
# https://archiveofourown.org/works/46263364?view_adult=true
# getting missing data 139/866
# https://archiveofourown.org/works/46263262?view_adult=true
# getting missing data 140/866
# https://archiveofourown.org/works/46262965?view_adult=true
# getting missing data 141/866
# https://archiveofourown.org/works/46258786?view_adult=true
# getting missing data 142/866
# https://archiveofourown.org/works/46242589?view_adult=true
# getting missing data 143/866
# https://archiveofourown.org/works/46237879?view_adult=true
# getting missing data 144/866
# https://archiveofourown.org/works/44968729?view_adult=true
# getting missing data 145/866
# https://archiveofourown.org/works/46222927?view_adult=true
# getting missing data 146/866
# https://archiveofourown.org/works/46222702?view_adult=true
# getting missing data 147/866
# https://archiveofourown.org/works/46219141?view_adult=true
# getting missing data 148/866
# https://archiveofourown.org/works/46163245?view_adult=true
# getting missing data 149/866
# https://archiveofourown.org/works/46212685?view_adult=true
# getting missing data 150/866
# https://archiveofourown.org/works/44824219?view_adult=true
# getting missing data 151/866
# https://archiveofourown.org/works/46207663?view_adult=true
# getting missing data 152/866
# https://archiveofourown.org/works/46188061?view_adult=true
# getting missing data 153/866
# https://archiveofourown.org/works/45994780?view_adult=true
# getting missing data 154/866
# https://archiveofourown.org/works/46199743?view_adult=true
# getting missing data 155/866
# https://archiveofourown.org/works/46199239?view_adult=true
# getting missing data 156/866
# https://archiveofourown.org/works/46179229?view_adult=true
# getting missing data 157/866
# https://archiveofourown.org/works/45689383?view_adult=true
# getting missing data 158/866
# https://archiveofourown.org/works/45620473?view_adult=true
# getting missing data 159/866
# https://archiveofourown.org/works/45608017?view_adult=true
# getting missing data 160/866
# https://archiveofourown.org/works/46159789?view_adult=true
# getting missing data 161/866
# https://archiveofourown.org/works/46158823?view_adult=true
# getting missing data 162/866
# https://archiveofourown.org/works/44911999?view_adult=true
# getting missing data 163/866
# https://archiveofourown.org/works/46156387?view_adult=true
# getting missing data 164/866
# https://archiveofourown.org/works/46153141?view_adult=true
# getting missing data 165/866
# https://archiveofourown.org/works/46012726?view_adult=true
# getting missing data 166/866
# https://archiveofourown.org/works/46151071?view_adult=true
# getting missing data 167/866
# https://archiveofourown.org/works/46148293?view_adult=true
# getting missing data 168/866
# https://archiveofourown.org/works/45740263?view_adult=true
# getting missing data 169/866
# https://archiveofourown.org/works/46140007?view_adult=true
# getting missing data 170/866
# https://archiveofourown.org/works/46134067?view_adult=true
# getting missing data 171/866
# https://archiveofourown.org/works/46111810?view_adult=true
# getting missing data 172/866
# https://archiveofourown.org/works/46111621?view_adult=true
# getting missing data 173/866
# https://archiveofourown.org/works/45731221?view_adult=true
# getting missing data 174/866
# https://archiveofourown.org/works/46105606?view_adult=true
# getting missing data 175/866
# https://archiveofourown.org/works/45982120?view_adult=true
# getting missing data 176/866
# https://archiveofourown.org/works/46103284?view_adult=true
# getting missing data 177/866
# https://archiveofourown.org/works/46103200?view_adult=true
# getting missing data 178/866
# https://archiveofourown.org/works/46102378?view_adult=true
# getting missing data 179/866
# https://archiveofourown.org/works/46102300?view_adult=true
# getting missing data 180/866
# https://archiveofourown.org/works/46101865?view_adult=true
# getting missing data 181/866
# https://archiveofourown.org/works/46101235?view_adult=true
# getting missing data 182/866
# https://archiveofourown.org/works/46106668?view_adult=true
# getting missing data 183/866
# https://archiveofourown.org/works/46090408?view_adult=true
# getting missing data 184/866
# https://archiveofourown.org/works/46086682?view_adult=true
# getting missing data 185/866
# https://archiveofourown.org/works/44860075?view_adult=true
# getting missing data 186/866
# https://archiveofourown.org/works/45707029?view_adult=true
# getting missing data 187/866
# https://archiveofourown.org/works/46080382?view_adult=true
# getting missing data 188/866
# https://archiveofourown.org/works/46077595?view_adult=true
# getting missing data 189/866
# https://archiveofourown.org/works/46014055?view_adult=true
# getting missing data 190/866
# https://archiveofourown.org/works/46077070?view_adult=true
# getting missing data 191/866
# https://archiveofourown.org/works/46076818?view_adult=true
# getting missing data 192/866
# https://archiveofourown.org/works/46071751?view_adult=true
# getting missing data 193/866
# https://archiveofourown.org/works/46070332?view_adult=true
# getting missing data 194/866
# https://archiveofourown.org/works/46070098?view_adult=true
# getting missing data 195/866
# https://archiveofourown.org/works/46067698?view_adult=true
# getting missing data 196/866
# https://archiveofourown.org/works/46047928?view_adult=true
# getting missing data 197/866
# https://archiveofourown.org/works/45359485?view_adult=true
# getting missing data 198/866
# https://archiveofourown.org/works/45726304?view_adult=true
# getting missing data 199/866
# https://archiveofourown.org/works/45916255?view_adult=true
# getting missing data 200/866
# https://archiveofourown.org/works/46042186?view_adult=true
# getting missing data 201/866
# https://archiveofourown.org/works/46040101?view_adult=true
# getting missing data 202/866
# https://archiveofourown.org/works/45992107?view_adult=true
# getting missing data 203/866
# https://archiveofourown.org/works/46037554?view_adult=true
# getting missing data 204/866
# https://archiveofourown.org/works/46035781?view_adult=true
# getting missing data 205/866
# https://archiveofourown.org/works/45601189?view_adult=true
# getting missing data 206/866
# https://archiveofourown.org/works/46034785?view_adult=true
# getting missing data 207/866
# https://archiveofourown.org/works/46027813?view_adult=true
# getting missing data 208/866
# https://archiveofourown.org/works/46026142?view_adult=true
# getting missing data 209/866
# https://archiveofourown.org/works/46025392?view_adult=true
# getting missing data 210/866
# https://archiveofourown.org/works/46021558?view_adult=true
# getting missing data 211/866
# https://archiveofourown.org/works/46015855?view_adult=true
# getting missing data 212/866
# https://archiveofourown.org/works/46015894?view_adult=true
# getting missing data 213/866
# https://archiveofourown.org/works/46014679?view_adult=true
# getting missing data 214/866
# https://archiveofourown.org/works/46011940?view_adult=true
# getting missing data 215/866
# https://archiveofourown.org/works/46011172?view_adult=true
# getting missing data 216/866
# https://archiveofourown.org/works/45179152?view_adult=true
# getting missing data 217/866
# https://archiveofourown.org/works/46004761?view_adult=true
# getting missing data 218/866
# https://archiveofourown.org/works/46004182?view_adult=true
# getting missing data 219/866
# https://archiveofourown.org/works/45673180?view_adult=true
# getting missing data 220/866
# https://archiveofourown.org/works/46001686?view_adult=true
# getting missing data 221/866
# https://archiveofourown.org/works/46000672?view_adult=true
# getting missing data 222/866
# https://archiveofourown.org/works/45987448?view_adult=true
# getting missing data 223/866
# https://archiveofourown.org/works/45986320?view_adult=true
# getting missing data 224/866
# https://archiveofourown.org/works/45985753?view_adult=true
# getting missing data 225/866
# https://archiveofourown.org/works/45985786?view_adult=true
# getting missing data 226/866
# https://archiveofourown.org/works/45984541?view_adult=true
# getting missing data 227/866
# https://archiveofourown.org/works/45982501?view_adult=true
# getting missing data 228/866
# https://archiveofourown.org/works/45981832?view_adult=true
# getting missing data 229/866
# https://archiveofourown.org/works/45977116?view_adult=true
# getting missing data 230/866
# https://archiveofourown.org/works/45976288?view_adult=true
# getting missing data 231/866
# https://archiveofourown.org/works/45972253?view_adult=true
# getting missing data 232/866
# https://archiveofourown.org/works/45973294?view_adult=true
# getting missing data 233/866
# https://archiveofourown.org/works/45969571?view_adult=true
# getting missing data 234/866
# https://archiveofourown.org/works/45961165?view_adult=true
# getting missing data 235/866
# https://archiveofourown.org/works/45943195?view_adult=true
# getting missing data 236/866
# https://archiveofourown.org/works/45806023?view_adult=true
# getting missing data 237/866
# https://archiveofourown.org/works/45959839?view_adult=true
# getting missing data 238/866
# https://archiveofourown.org/works/45959410?view_adult=true
# getting missing data 239/866
# https://archiveofourown.org/works/45959260?view_adult=true
# getting missing data 240/866
# https://archiveofourown.org/works/45958765?view_adult=true
# getting missing data 241/866
# https://archiveofourown.org/works/45958507?view_adult=true
# getting missing data 242/866
# https://archiveofourown.org/works/45956908?view_adult=true
# getting missing data 243/866
# https://archiveofourown.org/works/45956830?view_adult=true
# getting missing data 244/866
# https://archiveofourown.org/works/45956380?view_adult=true
# getting missing data 245/866
# https://archiveofourown.org/works/45898684?view_adult=true
# getting missing data 246/866
# https://archiveofourown.org/works/45955846?view_adult=true
# getting missing data 247/866
# https://archiveofourown.org/works/45270820?view_adult=true
# getting missing data 248/866
# https://archiveofourown.org/works/45949594?view_adult=true
# getting missing data 249/866
# https://archiveofourown.org/works/45949207?view_adult=true
# getting missing data 250/866
# https://archiveofourown.org/works/45949255?view_adult=true
# getting missing data 251/866
# https://archiveofourown.org/works/45948973?view_adult=true
# getting missing data 252/866
# https://archiveofourown.org/works/45948691?view_adult=true
# getting missing data 253/866
# https://archiveofourown.org/works/45299590?view_adult=true
# getting missing data 254/866
# https://archiveofourown.org/works/45946945?view_adult=true
# getting missing data 255/866
# https://archiveofourown.org/works/45946711?view_adult=true
# getting missing data 256/866
# https://archiveofourown.org/works/45946471?view_adult=true
# getting missing data 257/866
# https://archiveofourown.org/works/45944800?view_adult=true
# getting missing data 258/866
# https://archiveofourown.org/works/45941917?view_adult=true
# getting missing data 259/866
# https://archiveofourown.org/works/45939247?view_adult=true
# getting missing data 260/866
# https://archiveofourown.org/works/45926998?view_adult=true
# getting missing data 261/866
# https://archiveofourown.org/works/45926257?view_adult=true
# getting missing data 262/866
# https://archiveofourown.org/works/45088573?view_adult=true
# getting missing data 263/866
# https://archiveofourown.org/works/45575005?view_adult=true
# getting missing data 264/866
# https://archiveofourown.org/works/45923554?view_adult=true
# getting missing data 265/866
# https://archiveofourown.org/works/45923083?view_adult=true
# getting missing data 266/866
# https://archiveofourown.org/works/45922597?view_adult=true
# getting missing data 267/866
# https://archiveofourown.org/works/45921664?view_adult=true
# getting missing data 268/866
# https://archiveofourown.org/works/45919786?view_adult=true
# getting missing data 269/866
# https://archiveofourown.org/works/45781543?view_adult=true
# getting missing data 270/866
# https://archiveofourown.org/works/45917170?view_adult=true
# getting missing data 271/866
# https://archiveofourown.org/works/45917161?view_adult=true
# getting missing data 272/866
# https://archiveofourown.org/works/45915469?view_adult=true
# getting missing data 273/866
# https://archiveofourown.org/works/45907522?view_adult=true
# getting missing data 274/866
# https://archiveofourown.org/works/45907612?view_adult=true
# getting missing data 275/866
# https://archiveofourown.org/works/45906832?view_adult=true
# getting missing data 276/866
# https://archiveofourown.org/works/45906346?view_adult=true
# getting missing data 277/866
# https://archiveofourown.org/works/45904690?view_adult=true
# getting missing data 278/866
# https://archiveofourown.org/works/45903577?view_adult=true
# getting missing data 279/866
# https://archiveofourown.org/works/45901207?view_adult=true
# getting missing data 280/866
# https://archiveofourown.org/works/45900238?view_adult=true
# getting missing data 281/866
# https://archiveofourown.org/works/45900211?view_adult=true
# getting missing data 282/866
# https://archiveofourown.org/works/45898153?view_adult=true
# getting missing data 283/866
# https://archiveofourown.org/works/45898195?view_adult=true
# getting missing data 284/866
# https://archiveofourown.org/works/45890218?view_adult=true
# getting missing data 285/866
# https://archiveofourown.org/works/45889840?view_adult=true
# getting missing data 286/866
# https://archiveofourown.org/works/45874990?view_adult=true
# getting missing data 287/866
# https://archiveofourown.org/works/45888514?view_adult=true
# getting missing data 288/866
# https://archiveofourown.org/works/45887671?view_adult=true
# getting missing data 289/866
# https://archiveofourown.org/works/45906250?view_adult=true
# getting missing data 290/866
# https://archiveofourown.org/works/45886432?view_adult=true
# getting missing data 291/866
# https://archiveofourown.org/works/45885187?view_adult=true
# getting missing data 292/866
# https://archiveofourown.org/works/45885139?view_adult=true
# getting missing data 293/866
# https://archiveofourown.org/works/45883669?view_adult=true
# getting missing data 294/866
# https://archiveofourown.org/works/45880315?view_adult=true
# getting missing data 295/866
# https://archiveofourown.org/works/45874843?view_adult=true
# getting missing data 296/866
# https://archiveofourown.org/works/45844012?view_adult=true
# getting missing data 297/866
# https://archiveofourown.org/works/45797791?view_adult=true
# getting missing data 298/866
# https://archiveofourown.org/works/45525949?view_adult=true
# getting missing data 299/866
# https://archiveofourown.org/works/45858562?view_adult=true
# getting missing data 300/866
# https://archiveofourown.org/works/45825607?view_adult=true
# getting missing data 301/866
# https://archiveofourown.org/works/45228928?view_adult=true
# getting missing data 302/866
# https://archiveofourown.org/works/45430072?view_adult=true
# getting missing data 303/866
# https://archiveofourown.org/works/45822442?view_adult=true
# getting missing data 304/866
# https://archiveofourown.org/works/45820903?view_adult=true
# getting missing data 305/866
# https://archiveofourown.org/works/45820789?view_adult=true
# getting missing data 306/866
# https://archiveofourown.org/works/45820549?view_adult=true
# getting missing data 307/866
# https://archiveofourown.org/works/45796330?view_adult=true
# getting missing data 308/866
# https://archiveofourown.org/works/45795295?view_adult=true
# getting missing data 309/866
# https://archiveofourown.org/works/45792256?view_adult=true
# getting missing data 310/866
# https://archiveofourown.org/works/44781088?view_adult=true
# getting missing data 311/866
# https://archiveofourown.org/works/45104020?view_adult=true
# getting missing data 312/866
# https://archiveofourown.org/works/45778651?view_adult=true
# getting missing data 313/866
# https://archiveofourown.org/works/45774862?view_adult=true
# getting missing data 314/866
# https://archiveofourown.org/works/45771862?view_adult=true
# getting missing data 315/866
# https://archiveofourown.org/works/45749431?view_adult=true
# getting missing data 316/866
# https://archiveofourown.org/works/45768427?view_adult=true
# getting missing data 317/866
# https://archiveofourown.org/works/45768025?view_adult=true
# getting missing data 318/866
# https://archiveofourown.org/works/45545299?view_adult=true
# getting missing data 319/866
# https://archiveofourown.org/works/45758899?view_adult=true
# getting missing data 320/866
# https://archiveofourown.org/works/44842891?view_adult=true
# getting missing data 321/866
# https://archiveofourown.org/works/45733642?view_adult=true
# getting missing data 322/866
# https://archiveofourown.org/works/45729940?view_adult=true
# getting missing data 323/866
# https://archiveofourown.org/works/45728536?view_adult=true
# getting missing data 324/866
# https://archiveofourown.org/works/45726136?view_adult=true
# getting missing data 325/866
# https://archiveofourown.org/works/45412678?view_adult=true
# getting missing data 326/866
# https://archiveofourown.org/works/45714139?view_adult=true
# getting missing data 327/866
# https://archiveofourown.org/works/45604426?view_adult=true
# getting missing data 328/866
# https://archiveofourown.org/works/45711232?view_adult=true
# getting missing data 329/866
# https://archiveofourown.org/works/45708334?view_adult=true
# getting missing data 330/866
# https://archiveofourown.org/works/45707410?view_adult=true
# getting missing data 331/866
# https://archiveofourown.org/works/45703774?view_adult=true
# getting missing data 332/866
# https://archiveofourown.org/works/45703534?view_adult=true
# getting missing data 333/866
# https://archiveofourown.org/works/45695704?view_adult=true
# getting missing data 334/866
# https://archiveofourown.org/works/45683302?view_adult=true
# getting missing data 335/866
# https://archiveofourown.org/works/45679093?view_adult=true
# getting missing data 336/866
# https://archiveofourown.org/works/45309310?view_adult=true
# getting missing data 337/866
# https://archiveofourown.org/works/45675760?view_adult=true
# getting missing data 338/866
# https://archiveofourown.org/works/45674977?view_adult=true
# getting missing data 339/866
# https://archiveofourown.org/works/45381133?view_adult=true
# getting missing data 340/866
# https://archiveofourown.org/works/45665002?view_adult=true
# getting missing data 341/866
# https://archiveofourown.org/works/45664660?view_adult=true
# getting missing data 342/866
# https://archiveofourown.org/works/45413728?view_adult=true
# getting missing data 343/866
# https://archiveofourown.org/works/45660022?view_adult=true
# getting missing data 344/866
# https://archiveofourown.org/works/45410845?view_adult=true
# getting missing data 345/866
# https://archiveofourown.org/works/45632575?view_adult=true
# getting missing data 346/866
# https://archiveofourown.org/works/27141959?view_adult=true
# getting missing data 347/866
# https://archiveofourown.org/works/45630778?view_adult=true
# getting missing data 348/866
# https://archiveofourown.org/works/45626272?view_adult=true
# getting missing data 349/866
# https://archiveofourown.org/works/45624808?view_adult=true
# getting missing data 350/866
# https://archiveofourown.org/works/45624178?view_adult=true
# getting missing data 351/866
# https://archiveofourown.org/works/45618709?view_adult=true
# getting missing data 352/866
# https://archiveofourown.org/works/45613867?view_adult=true
# getting missing data 353/866
# https://archiveofourown.org/works/45607801?view_adult=true
# getting missing data 354/866
# https://archiveofourown.org/works/45606988?view_adult=true
# getting missing data 355/866
# https://archiveofourown.org/works/45600478?view_adult=true
# getting missing data 356/866
# https://archiveofourown.org/works/45594226?view_adult=true
# getting missing data 357/866
# https://archiveofourown.org/works/45590311?view_adult=true
# getting missing data 358/866
# https://archiveofourown.org/works/45579649?view_adult=true
# getting missing data 359/866
# https://archiveofourown.org/works/45577135?view_adult=true
# getting missing data 360/866
# https://archiveofourown.org/works/45577765?view_adult=true
# getting missing data 361/866
# https://archiveofourown.org/works/45574216?view_adult=true
# getting missing data 362/866
# https://archiveofourown.org/works/45575893?view_adult=true
# getting missing data 363/866
# https://archiveofourown.org/works/45575416?view_adult=true
# getting missing data 364/866
# https://archiveofourown.org/works/45575278?view_adult=true
# getting missing data 365/866
# https://archiveofourown.org/works/44845486?view_adult=true
# getting missing data 366/866
# https://archiveofourown.org/works/45568291?view_adult=true
# getting missing data 367/866
# https://archiveofourown.org/works/45567121?view_adult=true
# getting missing data 368/866
# https://archiveofourown.org/works/45107590?view_adult=true
# getting missing data 369/866
# https://archiveofourown.org/works/45565012?view_adult=true
# getting missing data 370/866
# https://archiveofourown.org/works/45376639?view_adult=true
# getting missing data 371/866
# https://archiveofourown.org/works/45017971?view_adult=true
# getting missing data 372/866
# https://archiveofourown.org/works/45426244?view_adult=true
# getting missing data 373/866
# https://archiveofourown.org/works/44825602?view_adult=true
# getting missing data 374/866
# https://archiveofourown.org/works/45537277?view_adult=true
# getting missing data 375/866
# https://archiveofourown.org/works/45441367?view_adult=true
# getting missing data 376/866
# https://archiveofourown.org/works/45528430?view_adult=true
# getting missing data 377/866
# https://archiveofourown.org/works/45236776?view_adult=true
# getting missing data 378/866
# https://archiveofourown.org/works/45526300?view_adult=true
# getting missing data 379/866
# https://archiveofourown.org/works/45525943?view_adult=true
# getting missing data 380/866
# https://archiveofourown.org/works/45519622?view_adult=true
# getting missing data 381/866
# https://archiveofourown.org/works/45525202?view_adult=true
# getting missing data 382/866
# https://archiveofourown.org/works/45525127?view_adult=true
# getting missing data 383/866
# https://archiveofourown.org/works/45512512?view_adult=true
# getting missing data 384/866
# https://archiveofourown.org/works/45512335?view_adult=true
# getting missing data 385/866
# https://archiveofourown.org/works/45511150?view_adult=true
# getting missing data 386/866
# https://archiveofourown.org/works/45507604?view_adult=true
# getting missing data 387/866
# https://archiveofourown.org/works/45363172?view_adult=true
# getting missing data 388/866
# https://archiveofourown.org/works/45505093?view_adult=true
# getting missing data 389/866
# https://archiveofourown.org/works/45504967?view_adult=true
# getting missing data 390/866
# https://archiveofourown.org/works/45504391?view_adult=true
# getting missing data 391/866
# https://archiveofourown.org/works/45504439?view_adult=true
# getting missing data 392/866
# https://archiveofourown.org/works/45499567?view_adult=true
# getting missing data 393/866
# https://archiveofourown.org/works/45495526?view_adult=true
# getting missing data 394/866
# https://archiveofourown.org/works/45477271?view_adult=true
# getting missing data 395/866
# https://archiveofourown.org/works/45431953?view_adult=true
# getting missing data 396/866
# https://archiveofourown.org/works/45477412?view_adult=true
# getting missing data 397/866
# https://archiveofourown.org/works/45473536?view_adult=true
# getting missing data 398/866
# https://archiveofourown.org/works/45472867?view_adult=true
# getting missing data 399/866
# https://archiveofourown.org/works/45450130?view_adult=true
# getting missing data 400/866
# https://archiveofourown.org/works/45446524?view_adult=true
# getting missing data 401/866
# https://archiveofourown.org/works/45463279?view_adult=true
# getting missing data 402/866
# https://archiveofourown.org/works/45461035?view_adult=true
# getting missing data 403/866
# https://archiveofourown.org/works/45438514?view_adult=true
# getting missing data 404/866
# https://archiveofourown.org/works/45460267?view_adult=true
# getting missing data 405/866
# https://archiveofourown.org/works/45457660?view_adult=true
# getting missing data 406/866
# https://archiveofourown.org/works/45457342?view_adult=true
# getting missing data 407/866
# https://archiveofourown.org/works/45447781?view_adult=true
# getting missing data 408/866
# https://archiveofourown.org/works/45453571?view_adult=true
# getting missing data 409/866
# https://archiveofourown.org/works/45452533?view_adult=true
# getting missing data 410/866
# https://archiveofourown.org/works/45429529?view_adult=true
# getting missing data 411/866
# https://archiveofourown.org/works/45428755?view_adult=true
# getting missing data 412/866
# https://archiveofourown.org/works/45427066?view_adult=true
# getting missing data 413/866
# https://archiveofourown.org/works/45422758?view_adult=true
# getting missing data 414/866
# https://archiveofourown.org/works/44740321?view_adult=true
# getting missing data 415/866
# https://archiveofourown.org/works/45417862?view_adult=true
# getting missing data 416/866
# https://archiveofourown.org/works/45416998?view_adult=true
# getting missing data 417/866
# https://archiveofourown.org/works/45412558?view_adult=true
# getting missing data 418/866
# https://archiveofourown.org/works/45409504?view_adult=true
# getting missing data 419/866
# https://archiveofourown.org/works/45406873?view_adult=true
# getting missing data 420/866
# https://archiveofourown.org/works/45234034?view_adult=true
# getting missing data 421/866
# https://archiveofourown.org/works/45403954?view_adult=true
# getting missing data 422/866
# https://archiveofourown.org/works/44929498?view_adult=true
# getting missing data 423/866
# https://archiveofourown.org/works/45381625?view_adult=true
# getting missing data 424/866
# https://archiveofourown.org/works/45380464?view_adult=true
# getting missing data 425/866
# https://archiveofourown.org/works/45377092?view_adult=true
# getting missing data 426/866
# https://archiveofourown.org/works/45377212?view_adult=true
# getting missing data 427/866
# https://archiveofourown.org/works/45369550?view_adult=true
# getting missing data 428/866
# https://archiveofourown.org/works/45367795?view_adult=true
# getting missing data 429/866
# https://archiveofourown.org/works/45365311?view_adult=true
# getting missing data 430/866
# https://archiveofourown.org/works/45365149?view_adult=true
# getting missing data 431/866
# https://archiveofourown.org/works/44715160?view_adult=true
# getting missing data 432/866
# https://archiveofourown.org/works/45361912?view_adult=true
# getting missing data 433/866
# https://archiveofourown.org/works/45361849?view_adult=true
# getting missing data 434/866
# https://archiveofourown.org/works/45129991?view_adult=true
# getting missing data 435/866
# https://archiveofourown.org/works/45360286?view_adult=true
# getting missing data 436/866
# https://archiveofourown.org/works/45342163?view_adult=true
# getting missing data 437/866
# https://archiveofourown.org/works/45023200?view_adult=true
# getting missing data 438/866
# https://archiveofourown.org/works/45336703?view_adult=true
# getting missing data 439/866
# https://archiveofourown.org/works/45336499?view_adult=true
# getting missing data 440/866
# https://archiveofourown.org/works/44791513?view_adult=true
# getting missing data 441/866
# https://archiveofourown.org/works/45330871?view_adult=true
# getting missing data 442/866
# https://archiveofourown.org/works/45329644?view_adult=true
# getting missing data 443/866
# https://archiveofourown.org/works/45324013?view_adult=true
# getting missing data 444/866
# https://archiveofourown.org/works/45232993?view_adult=true
# getting missing data 445/866
# https://archiveofourown.org/works/45318481?view_adult=true
# getting missing data 446/866
# https://archiveofourown.org/works/45317137?view_adult=true
# getting missing data 447/866
# https://archiveofourown.org/works/45312091?view_adult=true
# getting missing data 448/866
# https://archiveofourown.org/works/36746896?view_adult=true
# getting missing data 449/866
# https://archiveofourown.org/works/45269485?view_adult=true
# getting missing data 450/866
# https://archiveofourown.org/works/45268174?view_adult=true
# getting missing data 451/866
# https://archiveofourown.org/works/45261127?view_adult=true
# getting missing data 452/866
# https://archiveofourown.org/works/45261043?view_adult=true
# getting missing data 453/866
# https://archiveofourown.org/works/45260854?view_adult=true
# getting missing data 454/866
# https://archiveofourown.org/works/45259045?view_adult=true
# getting missing data 455/866
# https://archiveofourown.org/works/45257080?view_adult=true
# getting missing data 456/866
# https://archiveofourown.org/works/45256444?view_adult=true
# getting missing data 457/866
# https://archiveofourown.org/works/45253828?view_adult=true
# getting missing data 458/866
# https://archiveofourown.org/works/45247666?view_adult=true
# getting missing data 459/866
# https://archiveofourown.org/works/45257482?view_adult=true
# getting missing data 460/866
# https://archiveofourown.org/works/45238795?view_adult=true
# getting missing data 461/866
# https://archiveofourown.org/works/45195922?view_adult=true
# getting missing data 462/866
# https://archiveofourown.org/works/45194491?view_adult=true
# getting missing data 463/866
# https://archiveofourown.org/works/45189955?view_adult=true
# getting missing data 464/866
# https://archiveofourown.org/works/45189685?view_adult=true
# getting missing data 465/866
# https://archiveofourown.org/works/45134431?view_adult=true
# getting missing data 466/866
# https://archiveofourown.org/works/44893840?view_adult=true
# getting missing data 467/866
# https://archiveofourown.org/works/45187933?view_adult=true
# getting missing data 468/866
# https://archiveofourown.org/works/45187543?view_adult=true
# getting missing data 469/866
# https://archiveofourown.org/works/45059713?view_adult=true
# getting missing data 470/866
# https://archiveofourown.org/works/44822773?view_adult=true
# getting missing data 471/866
# https://archiveofourown.org/works/45178339?view_adult=true
# getting missing data 472/866
# https://archiveofourown.org/works/44793367?view_adult=true
# getting missing data 473/866
# https://archiveofourown.org/works/44887732?view_adult=true
# getting missing data 474/866
# https://archiveofourown.org/works/45152440?view_adult=true
# getting missing data 475/866
# https://archiveofourown.org/works/45145945?view_adult=true
# getting missing data 476/866
# https://archiveofourown.org/works/45143329?view_adult=true
# getting missing data 477/866
# https://archiveofourown.org/works/44791187?view_adult=true
# getting missing data 478/866
# https://archiveofourown.org/works/45141655?view_adult=true
# getting missing data 479/866
# https://archiveofourown.org/works/45141313?view_adult=true
# getting missing data 480/866
# https://archiveofourown.org/works/45141007?view_adult=true
# getting missing data 481/866
# https://archiveofourown.org/works/45134308?view_adult=true
# getting missing data 482/866
# https://archiveofourown.org/works/45130819?view_adult=true
# getting missing data 483/866
# https://archiveofourown.org/works/45099358?view_adult=true
# getting missing data 484/866
# https://archiveofourown.org/works/45119134?view_adult=true
# getting missing data 485/866
# https://archiveofourown.org/works/45111025?view_adult=true
# getting missing data 486/866
# https://archiveofourown.org/works/45108844?view_adult=true
# getting missing data 487/866
# https://archiveofourown.org/works/45103351?view_adult=true
# getting missing data 488/866
# https://archiveofourown.org/works/45092443?view_adult=true
# getting missing data 489/866
# https://archiveofourown.org/works/45084097?view_adult=true
# getting missing data 490/866
# https://archiveofourown.org/works/45082042?view_adult=true
# getting missing data 491/866
# https://archiveofourown.org/works/45075145?view_adult=true
# getting missing data 492/866
# https://archiveofourown.org/works/45074830?view_adult=true
# getting missing data 493/866
# https://archiveofourown.org/works/45070252?view_adult=true
# getting missing data 494/866
# https://archiveofourown.org/works/45067912?view_adult=true
# getting missing data 495/866
# https://archiveofourown.org/works/45067477?view_adult=true
# getting missing data 496/866
# https://archiveofourown.org/works/45062014?view_adult=true
# getting missing data 497/866
# https://archiveofourown.org/works/45058564?view_adult=true
# getting missing data 498/866
# https://archiveofourown.org/works/45057832?view_adult=true
# getting missing data 499/866
# https://archiveofourown.org/works/45028201?view_adult=true
# getting missing data 500/866
# https://archiveofourown.org/works/45024322?view_adult=true
# getting missing data 501/866
# https://archiveofourown.org/works/45023794?view_adult=true
# getting missing data 502/866
# https://archiveofourown.org/works/45013423?view_adult=true
# getting missing data 503/866
# https://archiveofourown.org/works/44985814?view_adult=true
# getting missing data 504/866
# https://archiveofourown.org/works/45010582?view_adult=true
# getting missing data 505/866
# https://archiveofourown.org/works/45010003?view_adult=true
# getting missing data 506/866
# https://archiveofourown.org/works/45008902?view_adult=true
# getting missing data 507/866
# https://archiveofourown.org/works/45008725?view_adult=true
# getting missing data 508/866
# https://archiveofourown.org/works/45006874?view_adult=true
# getting missing data 509/866
# https://archiveofourown.org/works/44982742?view_adult=true
# getting missing data 510/866
# https://archiveofourown.org/works/44994568?view_adult=true
# getting missing data 511/866
# https://archiveofourown.org/works/44991853?view_adult=true
# getting missing data 512/866
# https://archiveofourown.org/works/44029230?view_adult=true
# getting missing data 513/866
# https://archiveofourown.org/works/44938747?view_adult=true
# getting missing data 514/866
# https://archiveofourown.org/works/44930671?view_adult=true
# getting missing data 515/866
# https://archiveofourown.org/works/44930326?view_adult=true
# getting missing data 516/866
# https://archiveofourown.org/works/44928739?view_adult=true
# getting missing data 517/866
# https://archiveofourown.org/works/44894392?view_adult=true
# getting missing data 518/866
# https://archiveofourown.org/works/44835193?view_adult=true
# getting missing data 519/866
# https://archiveofourown.org/works/44918935?view_adult=true
# getting missing data 520/866
# https://archiveofourown.org/works/44850883?view_adult=true
# getting missing data 521/866
# https://archiveofourown.org/works/44908540?view_adult=true
# getting missing data 522/866
# https://archiveofourown.org/works/44907829?view_adult=true
# getting missing data 523/866
# https://archiveofourown.org/works/44904502?view_adult=true
# getting missing data 524/866
# https://archiveofourown.org/works/44882212?view_adult=true
# getting missing data 525/866
# https://archiveofourown.org/works/44681728?view_adult=true
# getting missing data 526/866
# https://archiveofourown.org/works/44871055?view_adult=true
# getting missing data 527/866
# https://archiveofourown.org/works/44870632?view_adult=true
# getting missing data 528/866
# https://archiveofourown.org/works/44867332?view_adult=true
# getting missing data 529/866
# https://archiveofourown.org/works/44864599?view_adult=true
# getting missing data 530/866
# https://archiveofourown.org/works/44864107?view_adult=true
# getting missing data 531/866
# https://archiveofourown.org/works/44860363?view_adult=true
# getting missing data 532/866
# https://archiveofourown.org/works/44843365?view_adult=true
# getting missing data 533/866
# https://archiveofourown.org/works/44840008?view_adult=true
# getting missing data 534/866
# https://archiveofourown.org/works/44835571?view_adult=true
# getting missing data 535/866
# https://archiveofourown.org/works/44830444?view_adult=true
# getting missing data 536/866
# https://archiveofourown.org/works/44826466?view_adult=true
# getting missing data 537/866
# https://archiveofourown.org/works/44824879?view_adult=true
# getting missing data 538/866
# https://archiveofourown.org/works/44820778?view_adult=true
# getting missing data 539/866
# https://archiveofourown.org/works/44793301?view_adult=true
# getting missing data 540/866
# https://archiveofourown.org/works/44782837?view_adult=true
# getting missing data 541/866
# https://archiveofourown.org/works/44774395?view_adult=true
# getting missing data 542/866
# https://archiveofourown.org/works/44766430?view_adult=true
# getting missing data 543/866
# https://archiveofourown.org/works/44763229?view_adult=true
# getting missing data 544/866
# https://archiveofourown.org/works/44744098?view_adult=true
# getting missing data 545/866
# https://archiveofourown.org/works/44584582?view_adult=true
# getting missing data 546/866
# https://archiveofourown.org/works/44740261?view_adult=true
# getting missing data 547/866
# ...
# getting missing data 726/866
# https://archiveofourown.org/works/20301736?view_adult=true
# getting missing data 727/866
# https://archiveofourown.org/works/22852282?view_adult=true
# getting missing data 728/866
# https://archiveofourown.org/works/22516711?view_adult=true
# getting missing data 729/866
# https://archiveofourown.org/works/21887239?view_adult=true
# getting missing data 730/866
# https://archiveofourown.org/works/22232230?view_adult=true
# getting missing data 731/866
# https://archiveofourown.org/works/22169317?view_adult=true
# getting missing data 732/866
# https://archiveofourown.org/works/22041079?view_adult=true
# getting missing data 733/866
# https://archiveofourown.org/works/20204818?view_adult=true
# getting missing data 734/866
# https://archiveofourown.org/works/21949393?view_adult=true
# getting missing data 735/866
# https://archiveofourown.org/works/21962311?view_adult=true
# getting missing data 736/866
# https://archiveofourown.org/works/21956920?view_adult=true
# getting missing data 737/866
# https://archiveofourown.org/works/21939082?view_adult=true
# getting missing data 738/866
# https://archiveofourown.org/works/21907027?view_adult=true
# getting missing data 739/866
# https://archiveofourown.org/works/21953470?view_adult=true
# getting missing data 740/866
# https://archiveofourown.org/works/20869007?view_adult=true
# getting missing data 741/866
# https://archiveofourown.org/works/21403063?view_adult=true
# getting missing data 742/866
# https://archiveofourown.org/works/21262232?view_adult=true
# getting missing data 743/866
# https://archiveofourown.org/works/21058028?view_adult=true
# getting missing data 744/866
# https://archiveofourown.org/works/20915507?view_adult=true
# getting missing data 745/866
# https://archiveofourown.org/works/20907440?view_adult=true
# getting missing data 746/866
# https://archiveofourown.org/works/20907296?view_adult=true
# getting missing data 747/866
# https://archiveofourown.org/works/20894279?view_adult=true
# getting missing data 748/866
# https://archiveofourown.org/works/20478287?view_adult=true
# getting missing data 749/866
# https://archiveofourown.org/works/20187292?view_adult=true
# getting missing data 750/866
# https://archiveofourown.org/works/20517794?view_adult=true
# getting missing data 751/866
# https://archiveofourown.org/works/20495744?view_adult=true
# getting missing data 752/866
# https://archiveofourown.org/works/19939318?view_adult=true
# getting missing data 753/866
# https://archiveofourown.org/works/17745068?view_adult=true
# getting missing data 754/866
# https://archiveofourown.org/works/19340686?view_adult=true
# getting missing data 755/866
# https://archiveofourown.org/works/17534789?view_adult=true
# getting missing data 756/866
# https://archiveofourown.org/works/18993673?view_adult=true
# getting missing data 757/866
# https://archiveofourown.org/works/18992584?view_adult=true
# getting missing data 758/866
# https://archiveofourown.org/works/18992062?view_adult=true
# getting missing data 759/866
# https://archiveofourown.org/works/17315441?view_adult=true
# getting missing data 760/866
# https://archiveofourown.org/works/18376742?view_adult=true
# getting missing data 761/866
# https://archiveofourown.org/works/18352004?view_adult=true
# getting missing data 762/866
# https://archiveofourown.org/works/18280280?view_adult=true
# getting missing data 763/866
# https://archiveofourown.org/works/18222716?view_adult=true
# getting missing data 764/866
# https://archiveofourown.org/works/18222464?view_adult=true
# getting missing data 765/866
# https://archiveofourown.org/works/18222374?view_adult=true
# getting missing data 766/866
# https://archiveofourown.org/works/18134861?view_adult=true
# getting missing data 767/866
# https://archiveofourown.org/works/17174525?view_adult=true
# getting missing data 768/866
# https://archiveofourown.org/works/17042135?view_adult=true
# getting missing data 769/866
# https://archiveofourown.org/works/17081909?view_adult=true
# getting missing data 770/866
# https://archiveofourown.org/works/17076665?view_adult=true
# getting missing data 771/866
# https://archiveofourown.org/works/16603055?view_adult=true
# getting missing data 772/866
# https://archiveofourown.org/works/16511738?view_adult=true
# getting missing data 773/866
# https://archiveofourown.org/works/16382582?view_adult=true
# getting missing data 774/866
# https://archiveofourown.org/works/16422308?view_adult=true
# getting missing data 775/866
# https://archiveofourown.org/works/15523572?view_adult=true
# getting missing data 776/866
# https://archiveofourown.org/works/16365344?view_adult=true
# getting missing data 777/866
# https://archiveofourown.org/works/16274480?view_adult=true
# getting missing data 778/866
# https://archiveofourown.org/works/16177334?view_adult=true
# getting missing data 779/866
# https://archiveofourown.org/works/15990740?view_adult=true
# getting missing data 780/866
# https://archiveofourown.org/works/15561858?view_adult=true
# getting missing data 781/866
# https://archiveofourown.org/works/15400686?view_adult=true
# getting missing data 782/866
# https://archiveofourown.org/works/15402921?view_adult=true
# getting missing data 783/866
# https://archiveofourown.org/works/15392799?view_adult=true
# getting missing data 784/866
# https://archiveofourown.org/works/15324873?view_adult=true
# getting missing data 785/866
# https://archiveofourown.org/works/15323526?view_adult=true
# getting missing data 786/866
# https://archiveofourown.org/works/15305190?view_adult=true
# getting missing data 787/866
# https://archiveofourown.org/works/15261393?view_adult=true
# getting missing data 788/866
# https://archiveofourown.org/works/15261348?view_adult=true
# getting missing data 789/866
# https://archiveofourown.org/works/15261306?view_adult=true
# getting missing data 790/866
# https://archiveofourown.org/works/15261186?view_adult=true
# getting missing data 791/866
# https://archiveofourown.org/works/15241080?view_adult=true
# getting missing data 792/866
# https://archiveofourown.org/works/15088985?view_adult=true
# getting missing data 793/866
# https://archiveofourown.org/works/14973011?view_adult=true
# getting missing data 794/866
# https://archiveofourown.org/works/14894105?view_adult=true
# getting missing data 795/866
# https://archiveofourown.org/works/14888337?view_adult=true
# getting missing data 796/866
# https://archiveofourown.org/works/14846627?view_adult=true
# getting missing data 797/866
# https://archiveofourown.org/works/14802308?view_adult=true
# getting missing data 798/866
# https://archiveofourown.org/works/14729288?view_adult=true
# getting missing data 799/866
# https://archiveofourown.org/works/46211047?view_adult=true
# getting missing data 800/866
# https://archiveofourown.org/works/33837037?view_adult=true
# getting missing data 801/866
# https://archiveofourown.org/works/14418399?view_adult=true
# getting missing data 802/866
# https://archiveofourown.org/works/14131158?view_adult=true
# getting missing data 803/866
# https://archiveofourown.org/works/13833576?view_adult=true
# getting missing data 804/866
# https://archiveofourown.org/works/13807095?view_adult=true
# getting missing data 805/866
# https://archiveofourown.org/works/13439295?view_adult=true
# getting missing data 806/866
# https://archiveofourown.org/works/13689675?view_adult=true
# getting missing data 807/866
# https://archiveofourown.org/works/13488987?view_adult=true
# getting missing data 808/866
# https://archiveofourown.org/works/13427568?view_adult=true
# getting missing data 809/866
# https://archiveofourown.org/works/13384536?view_adult=true
# getting missing data 810/866
# https://archiveofourown.org/works/13318089?view_adult=true
# getting missing data 811/866
# https://archiveofourown.org/works/13250715?view_adult=true
# getting missing data 812/866
# https://archiveofourown.org/works/46210537?view_adult=true
# getting missing data 813/866
# https://archiveofourown.org/works/13028247?view_adult=true
# getting missing data 814/866
# https://archiveofourown.org/works/5754256?view_adult=true
# getting missing data 815/866
# https://archiveofourown.org/works/12472404?view_adult=true
# getting missing data 816/866
# https://archiveofourown.org/works/11878443?view_adult=true
# getting missing data 817/866
# https://archiveofourown.org/works/11875134?view_adult=true
# getting missing data 818/866
# https://archiveofourown.org/works/11817630?view_adult=true
# getting missing data 819/866
# https://archiveofourown.org/works/8661736?view_adult=true
# getting missing data 820/866
# https://archiveofourown.org/works/11682549?view_adult=true
# getting missing data 821/866
# https://archiveofourown.org/works/11682078?view_adult=true
# getting missing data 822/866
# https://archiveofourown.org/works/11286780?view_adult=true
# getting missing data 823/866
# https://archiveofourown.org/works/8568871?view_adult=true
# getting missing data 824/866
# https://archiveofourown.org/works/11008230?view_adult=true
# getting missing data 825/866
# https://archiveofourown.org/works/10999392?view_adult=true
# getting missing data 826/866
# https://archiveofourown.org/works/10990965?view_adult=true
# getting missing data 827/866
# https://archiveofourown.org/works/10928415?view_adult=true
# getting missing data 828/866
# https://archiveofourown.org/works/8964634?view_adult=true
# getting missing data 829/866
# https://archiveofourown.org/works/9548522?view_adult=true
# getting missing data 830/866
# https://archiveofourown.org/works/9490682?view_adult=true
# getting missing data 831/866
# https://archiveofourown.org/works/9062950?view_adult=true
# getting missing data 832/866
# https://archiveofourown.org/works/9057463?view_adult=true
# getting missing data 833/866
# https://archiveofourown.org/works/8786551?view_adult=true
# getting missing data 834/866
# https://archiveofourown.org/works/8783401?view_adult=true
# getting missing data 835/866
# https://archiveofourown.org/works/8739550?view_adult=true
# getting missing data 836/866
# https://archiveofourown.org/works/8731648?view_adult=true
# getting missing data 837/866
# https://archiveofourown.org/works/8666605?view_adult=true
# getting missing data 838/866
# https://archiveofourown.org/works/8667433?view_adult=true
# getting missing data 839/866
# https://archiveofourown.org/works/8666857?view_adult=true
# getting missing data 840/866
# https://archiveofourown.org/works/8625964?view_adult=true
# getting missing data 841/866
# https://archiveofourown.org/works/8456017?view_adult=true
# getting missing data 842/866
# https://archiveofourown.org/works/8315419?view_adult=true
# getting missing data 843/866
# https://archiveofourown.org/works/8107966?view_adult=true
# getting missing data 844/866
# https://archiveofourown.org/works/7898905?view_adult=true
# getting missing data 845/866
# https://archiveofourown.org/works/7849768?view_adult=true
# getting missing data 846/866
# https://archiveofourown.org/works/7568299?view_adult=true
# getting missing data 847/866
# https://archiveofourown.org/works/7567216?view_adult=true
# getting missing data 848/866
# https://archiveofourown.org/works/7334200?view_adult=true
# getting missing data 849/866
# https://archiveofourown.org/works/34292530?view_adult=true
# getting missing data 850/866
# https://archiveofourown.org/works/6172984?view_adult=true
# getting missing data 851/866
# https://archiveofourown.org/works/6743134?view_adult=true
# getting missing data 852/866
# https://archiveofourown.org/works/6556612?view_adult=true
# getting missing data 853/866
# https://archiveofourown.org/works/3841069?view_adult=true
# getting missing data 854/866
# https://archiveofourown.org/works/5861695?view_adult=true
# getting missing data 855/866
# https://archiveofourown.org/works/5726503?view_adult=true
# getting missing data 856/866
# https://archiveofourown.org/works/5443742?view_adult=true
# getting missing data 857/866
# https://archiveofourown.org/works/4774295?view_adult=true
# getting missing data 858/866
# https://archiveofourown.org/works/4483883?view_adult=true
# getting missing data 859/866
# https://archiveofourown.org/works/4182219?view_adult=true
# getting missing data 860/866
# https://archiveofourown.org/works/4182480?view_adult=true
# getting missing data 861/866
# https://archiveofourown.org/works/3846424?view_adult=true
# getting missing data 862/866
# https://archiveofourown.org/works/3709479?view_adult=true
# getting missing data 863/866
# https://archiveofourown.org/works/2282274?view_adult=true
# getting missing data 864/866
# https://archiveofourown.org/works/1267453?view_adult=true
# getting missing data 865/866
# https://archiveofourown.org/works/1169828?view_adult=true
# getting missing data 866/866
# https://archiveofourown.org/works/1084801?view_adult=true
#                                            link  \
# 32   https://archiveofourown.org/works/46544200
# 394  https://archiveofourown.org/works/45431953
# 408  https://archiveofourown.org/works/45452533
# 444  https://archiveofourown.org/works/45318481
# 483  https://archiveofourown.org/works/45119134
# 668  https://archiveofourown.org/works/28030506
# 727  https://archiveofourown.org/works/22516711
# 738  https://archiveofourown.org/works/21953470
# 769  https://archiveofourown.org/works/17076665
# 777  https://archiveofourown.org/works/16177334
#
#                                                warning  \
# 32                           No Archive Warnings Apply
# 394          Creator Chose Not To Use Archive Warnings
# 408          Creator Chose Not To Use Archive Warnings
# 444          Creator Chose Not To Use Archive Warnings
# 483                          No Archive Warnings Apply
# 668                          No Archive Warnings Apply
# 727          Creator Chose Not To Use Archive Warnings
# 738                          No Archive Warnings Apply
# 769  Graphic Depictions Of ViolenceMajor Character ...
# 777          Creator Chose Not To Use Archive Warnings
#
#                           mainship  \
# 32   Lucy Carlyle/Anthony Lockwood
# 394  Lucy Carlyle/Anthony Lockwood
# 408  Lucy Carlyle/Anthony Lockwood
# 444  Lucy Carlyle/Anthony Lockwood
# 483  Lucy Carlyle/Anthony Lockwood
# 668                           None
# 727  Lucy Carlyle/Anthony Lockwood
# 738  Lucy Carlyle/Anthony Lockwood
# 769  Lucy Carlyle/Anthony Lockwood
# 777                           None
#
#                                           relationship  \
# 32                     [Lucy Carlyle/Anthony Lockwood]
# 394  [Lucy Carlyle/Anthony Lockwood, Lucy Carlyle &...
# 408  [Lucy Carlyle/Anthony Lockwood, Flo Bones/Geor...
# 444  [Lucy Carlyle/Anthony Lockwood, Lucy Carlyle &...
# 483  [Lucy Carlyle/Anthony Lockwood, Lucy Carlyle &...
# 668                                                 []
# 727                    [Lucy Carlyle/Anthony Lockwood]
# 738                    [Lucy Carlyle/Anthony Lockwood]
# 769  [Lucy Carlyle/Anthony Lockwood, Lucy Carlyle/G...
# 777                                                 []
#
#                                             characters  \
# 32                    [Lucy Carlyle, Anthony Lockwood]
# 394  [Anthony Lockwood, Lucy Carlyle, George Cubbin...
# 408  [Anthony Lockwood, Lucy Carlyle, Flo Bones, Ge...
# 444  [Lucy Carlyle, Anthony Lockwood, George Cubbin...
# 483  [Lucy Carlyle, Anthony Lockwood, George Cubbin...
# 668  [Harry Potter, Albus Dumbledore, Lucy Carlyle,...
# 727   [Lucy Carlyle, Anthony Lockwood, George Cubbins]
# 738                      [George Cubbins, Quill Kipps]
# 769                   [Anthony Lockwood, Bobby Vernon]
# 777  [Lucy Carlyle, The Skull (Lockwood & Co), Geor...
#
#                                                   tags summary
# 32   [Newly established relationship, Angst, Hurt/C...     NaN
# 394  [Smut, Not Safe for Pandas, Angst, Fluff, Poor...     NaN
# 408  [Modern AU, Locklyle, locklyle demi, Alternate...     NaN
# 444  [Found Family, Locklyle, First Kiss, Alternate...     NaN
# 483                                        [Episode 3]     NaN
# 668  [Crossover randomly, no real plot, Crack, Bad ...     NaN
# 727                  [Truth or Dare, Getting Together]     NaN
# 738  [Secret Santa, Historical AU - Regency Era, Ep...     NaN
# 769  [Implied/Referenced Character Death, Past Viol...     NaN
# 777                                            [Humor]     NaN

# %%
final=part1.merge(part2, how='outer', on='link')
final=final.merge(part3, how='outer', on='link')
final.to_csv('ao3_lockwood_and_co.csv', index=False)

# %%
rating=[]
counter=0
for x in final[link]:
    newlink=x+'?view_adult=true'
    counter+=1
    print(f"getting missing data {counter}/{len(final['link'])}")
    print(newlink)
    source = requests.get(newlink, headers={
                          'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64)'}).text
    soup = BeautifulSoup(source,'html.parser')
    rating_tag=soup.find('dd', attrs={'class':'rating tags'}).get_text().replace('\n','').strip()
    rating.append(rating_tag)
    time.sleep(10)
    final[rating] = rating
final.to_csv.to_csv('ao3_lockwood_and_co.csv', index=False)
